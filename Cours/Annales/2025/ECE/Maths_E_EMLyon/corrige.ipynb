# %% [markdown]
# # Corrigé Sujet Maths EMLyon 2025 ECE

# %%
import matplotlib . pyplot as plt
import numpy as np
import pandas as pd
import numpy.random as rd

# %% [markdown]
# ## Exercice 1 : Partie A - Question 2

# %%
u = 1
n = 0

while u < 10**6:
    u = u * np.exp(1 / u)
    n = n + 1
    
print(n)

# %% [markdown]
# ## Exercice 2 : Partie B - Question 9

# %%
def voisins(A, i):
    n = len(A[i])
    V = []
    for j in range(n):
        if j != i and A[i, j] != 0:
            V.append(j)
    return V

# %% [markdown]
# ## Exercice 2 : Partie B - Question 10

# %%
def min_ext(L):
    m = 0
    while m in L:
        m = m + 1
    return m
# Out:
# 2.63

# %% [markdown]
# ## Exercice 2 : Partie B - Question 10

# %%
def coloration(A):
    n = len(A[0])
    C = [k for k in range(0, n)]
    for i in range(1, n):
        C_voisins = [C[j] for j in voisins(A, i)]
        C[i] = min_ext(C_voisins)
    return C

# %% [markdown]
# ## Exercice 3 : Partie C - Question 5 (a)

# %% [markdown]
# SELECT montant FROM sinistres WHERE annee = 2024;

# %% [markdown]
# ## Exercice 3 : Partie C - Question 5 (b)

# %% [markdown]
# SELECT mois, annee FROM sinistres WHERE montant > 1000000;

# %% [markdown]
# ## Exercice 3 : Partie C - Question 6

# %% [markdown]
# INSERT INTO sinistres VALUES (7652, 2025, 'avril', 1540);
